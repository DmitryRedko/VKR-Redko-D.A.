# %%
from stocks_parser import StockParser

stock_parser = StockParser(['SBER','GAZP'],start_date='2023-12-20')

stock_parser.parse_stocks()
stock_parser.plot_stock_data()
df = stock_parser.get_stocks_dataframe()

# %%
df['SBER']
# Out:
#     ticker per       date  time    open    high     low   close       vol
# 0     SBER   D 2023-01-20     0  149.70  151.40  148.64  151.38  44165570
# 1     SBER   D 2023-01-23     0  151.90  154.10  151.01  153.50  55100140
# 2     SBER   D 2023-01-24     0  153.94  155.58  152.28  152.66  78662030
# 3     SBER   D 2023-01-25     0  152.45  153.60  151.50  152.81  43317800
# 4     SBER   D 2023-01-26     0  153.32  154.30  151.73  152.40  45375340
# ..     ...  ..        ...   ...     ...     ...     ...     ...       ...
# 246   SBER   D 2024-01-10     0  275.30  276.16  273.64  274.49  20618950
# 247   SBER   D 2024-01-11     0  274.62  275.97  274.01  275.71  19520470
# 248   SBER   D 2024-01-12     0  275.90  276.96  274.77  275.84  17608350
# 249   SBER   D 2024-01-15     0  276.30  277.73  275.21  275.96  21283290
# 250   SBER   D 2024-01-16     0  276.24  276.45  274.10  274.99  10026260
#
# [251 rows x 9 columns]

# %%
df['GAZP']
# Out:
#     ticker per       date  time    open    high     low   close       vol
# 0     GAZP   D 2023-01-20     0  160.60  161.45  158.55  158.85  16500690
# 1     GAZP   D 2023-01-23     0  158.90  160.49  158.20  160.06  15042680
# 2     GAZP   D 2023-01-24     0  160.22  160.83  157.44  157.88  16613760
# 3     GAZP   D 2023-01-25     0  157.90  159.13  156.71  158.99  15559500
# 4     GAZP   D 2023-01-26     0  159.14  159.43  157.13  157.58  12370220
# ..     ...  ..        ...   ...     ...     ...     ...     ...       ...
# 246   GAZP   D 2024-01-10     0  162.41  163.70  162.00  162.87  10743240
# 247   GAZP   D 2024-01-11     0  162.92  162.93  161.93  162.50  13085980
# 248   GAZP   D 2024-01-12     0  162.55  163.98  162.20  163.37  14743890
# 249   GAZP   D 2024-01-15     0  163.80  164.40  163.26  163.34  11051540
# 250   GAZP   D 2024-01-16     0  163.28  163.50  162.37  163.03   7116690
#
# [251 rows x 9 columns]
