# %%
from news_parser import NewsParser

sberbank_keywords = ["СБЕР", "Сбербанк", "Сбер", "Сберколл", "Сбербизнес", "Сбертек", "Сбермаркет", "Мегамаркет", "Греф", "Сберколлектор", "Сбербизнес", "Сбертек", "Сбермаркет", "СберЛогистика", "СберЛизинг", "СберНедвижимость", "Сбербанк-АСТ", "Сбербанк-Резерв", "Сбербанк-Спасение", "Сбербанк-Страхование", "Сбербанк-Технологии", "Сбербанк-Эквайринг", "Сбербанк-Эксперт", "Сбербанк-Контактный Центр"]

news_parser = NewsParser("https://bcs-express.ru/category/sberbank", sberbank_keywords)

news_parser.parse_news(stop_date='2023-12-20')
dataset = news_parser.get_news_dataframe()
news_parser.save_to_csv('SBER.csv')
dataset
# Out:
# News parsed successfully: 10
# News parsed successfully: 20
#           date                                              title  \
# 0   2024-01-16  Сбербанк. Не удалось обновить январские максимумы
# 1   2024-01-15  Сбербанк. Сбавили темпы, но краткосрочный трен...
# 2   2024-01-12                   Сбербанк. Пока не расторговались
# 3   2024-01-11  Сбербанк. Может протестировать 200-часовую сре...
# 4   2024-01-10               Фавориты стратегии 2024: рост до 12%
# 5   2024-01-10  Портфели БКС. Фавориты выросли на 9%, а аутсай...
# 6   2024-01-10                 Сбербанк. Откат на низких оборотах
# 7   2024-01-09  5 идей в российских акциях. На какие бумаги об...
# 8   2024-01-09                Сбербанк. Ориентиры смещаются к 280
# 9   2024-01-03                    Сбербанк. За год выросли на 92%
# 10  2023-12-29  Закрываем идею в Сбере: доходность с открытия ...
# 11  2023-12-29      Сбербанк. Отскочили от динамической поддержки
# ...

# %%
from news_parser import NewsParser

gazp_keywords = ["GAZP", "Газстройпром", "Газпром", "Газпромнефть", "Газпромбанк", "Газпроммедиа", "Газпромтранс", "Газпромдобыча", "Газпромэнерго", "Газпромавиа", "Газпроммежрегионгаз", "Газпроминвестходинг", "Газпромнедра", "Газпромпереработка", "Газпромпоставка", "Газпроммонтаж", "Газпромвнешэкономбанк", "Газпромснаб", "Газпромавтоматизация", "Газпромкомплектация", "Газпромгазораспределение", "Газпромэнергосбыт", "Газпромнефтегаз", "Газпромгазэнергосбыт", "Газпромкапитал", "Газпромстрой", "Газпромнефтьцентр", "Газпромтрансгаз", "Газпромбурение", "Газпромперевозка", "Газпромавтоматика"]

news_parser = NewsParser("https://bcs-express.ru/category/gazprom", gazp_keywords)

news_parser.parse_news(stop_date='2023-12-20')
dataset = news_parser.get_news_dataframe()
news_parser.save_to_csv('GAZP.csv')
dataset
# Out:
# News parsed successfully: 10
# News parsed successfully: 20
#           date                                              title  \
# 0   2024-01-16                        Газпром. Перерыв на подъеме
# 1   2024-01-15  Мнение аналитиков. Рекордные поставки газа в К...
# 2   2024-01-15               Газпром. Восходящая тенденция в силе
# 3   2024-01-12               Газпром. Консолидация над поддержкой
# 4   2024-01-11                             Газпром. Неубедительно
# 5   2024-01-10  Мнение аналитиков. Цены на газ в Европе и Азии...
# 6   2024-01-10                        Газпром. Тенденция сломлена
# 7   2024-01-09                        Газпром. В локальном тренде
# 8   2024-01-04  Газпром обновил рекорд суточных поставок газа ...
# 9   2024-01-03         Акции растут широким фронтом, рубль падает
# 10  2024-01-03                 Газпром. Цена держится у поддержки
# 11  2023-12-29              Газпром. Потенциал снижения исчерпан?
# ...
